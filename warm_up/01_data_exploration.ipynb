# %% [markdown]
# # References

# %% [markdown]
# Section Data Exploration is partially based on:
# - https://www.kaggle.com/andredornas/tp2-walmart-sales-forecast/notebook#Data-manipulation
# - https://www.kaggle.com/nsawal/walmart-baseline-sales-forecasting-lstm

# %% [markdown]
# #  Import Packages

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(style="ticks")
from statsmodels.tsa.stattools import acf, pacf
from scipy.signal import periodogram

# %% [markdown]
# # Import Data

# %%
home_dir = os.getcwd()
data_dir = home_dir + '\data\input'
data_preprocessed_dir = home_dir + '\data\preprocessed'
print(home_dir)
print(data_dir)
print(data_preprocessed_dir)
# Out:
# C:\dev\predicting-sales-data\warm_up
# C:\dev\predicting-sales-data\warm_up\data\input
# C:\dev\predicting-sales-data\warm_up\data\preprocessed

# %%
df_store = pd.read_csv(data_dir + '/stores.csv')
df_feature = pd.read_csv(data_dir + '/features.csv')
df_train = pd.read_csv(data_dir + '/train.csv')
df_test = pd.read_csv(data_dir + '/test.csv')

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Stores Data

# %%
df_store.head().append(df_store.tail())
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
print("Structure of Store:\n", df_store.shape, '\n')
print("Number of missing values:\n",
      df_store.isnull().sum().sort_values(ascending=False), "\n")
# Out:
# Structure of Store:
#  (45, 3)
#
# Number of missing values:
#  Size     0
# Type     0
# Store    0
# dtype: int64

# %% [markdown]
# ### Feature Data

# %%
df_feature
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
df_feature.describe()
# Out:
#              Store  Temperature   Fuel_Price      MarkDown1      MarkDown2  \
# count  8190.000000  8190.000000  8190.000000    4032.000000    2921.000000
# mean     23.000000    59.356198     3.405992    7032.371786    3384.176594
# std      12.987966    18.678607     0.431337    9262.747448    8793.583016
# min       1.000000    -7.290000     2.472000   -2781.450000    -265.760000
# 25%      12.000000    45.902500     3.041000    1577.532500      68.880000
# 50%      23.000000    60.710000     3.513000    4743.580000     364.570000
# 75%      34.000000    73.880000     3.743000    8923.310000    2153.350000
# max      45.000000   101.950000     4.468000  103184.980000  104519.540000
#
#            MarkDown3     MarkDown4      MarkDown5          CPI  Unemployment
# count    3613.000000   3464.000000    4050.000000  7605.000000   7605.000000
# mean     1760.100180   3292.935886    4132.216422   172.460809      7.826821
# std     11276.462208   6792.329861   13086.690278    39.738346      1.877259
# min      -179.260000      0.220000    -185.170000   126.064000      3.684000
# 25%         6.600000    304.687500    1440.827500   132.364839      6.634000
# 50%        36.260000   1176.425000    2727.135000   182.764003      7.806000
# 75%       163.150000   3310.007500    4832.555000   213.932412      8.567000
# max    149483.310000  67474.850000  771448.100000   228.976456     14.313000

# %%
print("Structure of Feature: ", df_feature.shape, "\n")
print("Count of missing values:\n", df_feature.isnull(
).sum().sort_values(ascending=False), "\n")
# Out:
# Structure of Feature:  (8190, 12)
#
# Count of missing values:
#  MarkDown2       5269
# MarkDown4       4726
# MarkDown3       4577
# MarkDown1       4158
# MarkDown5       4140
# Unemployment     585
# CPI              585
# IsHoliday          0
# Fuel_Price         0
# Temperature        0
# Date               0
# Store              0
# dtype: int64

# %%
feature_percent_missing = df_feature.isnull().sum()*100/len(df_feature)
feature_data_type = df_feature.dtypes

feature_summary = pd.DataFrame({"Percent_missing": feature_percent_missing.round(2),
                                "Datatypes": feature_data_type})

feature_summary
# Out:
#               Percent_missing Datatypes
# Store                    0.00     int64
# Date                     0.00    object
# Temperature              0.00   float64
# Fuel_Price               0.00   float64
# MarkDown1               50.77   float64
# MarkDown2               64.33   float64
# MarkDown3               55.89   float64
# MarkDown4               57.70   float64
# MarkDown5               50.55   float64
# CPI                      7.14   float64
# Unemployment             7.14   float64
# IsHoliday                0.00      bool

# %% [markdown]
# ### Train Data

# %%
df_train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
print("Structure of train:\n", df_train.shape, "\n")
print("Summary Statistic:\n", df_train.describe(), "\n")
# Out:
# Structure of train:
#  (421570, 5)
#
# Summary Statistic:
#                 Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
train_percent_missing = df_train.isnull().sum()*100/len(df_train)
train_datatype = df_train.dtypes

train_summary = pd.DataFrame({"Percent_Missing": train_percent_missing.round(2),
                              "Datatypes": train_datatype})

train_summary
# Out:
#               Percent_Missing Datatypes
# Store                     0.0     int64
# Dept                      0.0     int64
# Date                      0.0    object
# Weekly_Sales              0.0   float64
# IsHoliday                 0.0      bool

# %% [markdown]
# ### Test Data

# %%
df_test
# Out:
#         Store  Dept        Date  IsHoliday
# 0           1     1  2012-11-02      False
# 1           1     1  2012-11-09      False
# 2           1     1  2012-11-16      False
# 3           1     1  2012-11-23       True
# 4           1     1  2012-11-30      False
# ...       ...   ...         ...        ...
# 115059     45    98  2013-06-28      False
# 115060     45    98  2013-07-05      False
# 115061     45    98  2013-07-12      False
# 115062     45    98  2013-07-19      False
# 115063     45    98  2013-07-26      False
#
# [115064 rows x 4 columns]

# %%
print("Structure of test:\n", df_test.shape, "\n")
print("Summary Statistic:\n", df_test.describe(), "\n")
# Out:
# Structure of test:
#  (115064, 4)
#
# Summary Statistic:
#                 Store           Dept
# count  115064.000000  115064.000000
# mean       22.238207      44.339524
# std        12.809930      30.656410
# min         1.000000       1.000000
# 25%        11.000000      18.000000
# 50%        22.000000      37.000000
# 75%        33.000000      74.000000
# max        45.000000      99.000000

# %%
test_percent_missing = df_test.isnull().sum()*100/len(df_test)
test_datatypes = df_test.dtypes

test_summary = pd.DataFrame({"Datatypes": test_datatypes,
                             "Percent_Missing": test_percent_missing.round(2)})

test_summary
# Out:
#           Datatypes  Percent_Missing
# Store         int64              0.0
# Dept          int64              0.0
# Date         object              0.0
# IsHoliday      bool              0.0

# %% [markdown]
# # Merge Datasets

# %%
df_merged = df_train.merge(df_store, how='left').merge(df_feature, how='left')

# %%
df_merged
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1  2010-02-05      24924.50      False    A  151315
# 1           1     1  2010-02-12      46039.49       True    A  151315
# 2           1     1  2010-02-19      41595.55      False    A  151315
# 3           1     1  2010-02-26      19403.54      False    A  151315
# 4           1     1  2010-03-05      21827.90      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    98  2012-09-28        508.37      False    B  118221
# 421566     45    98  2012-10-05        628.10      False    B  118221
# 421567     45    98  2012-10-12       1061.02      False    B  118221
# 421568     45    98  2012-10-19        760.01      False    B  118221
# 421569     45    98  2012-10-26       1076.80      False    B  118221
#
#         Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  \
# 0             42.31       2.572        NaN        NaN        NaN        NaN
# 1             38.51       2.548        NaN        NaN        NaN        NaN
# 2             39.93       2.514        NaN        NaN        NaN        NaN
# 3             46.63       2.561        NaN        NaN        NaN        NaN
# 4             46.50       2.625        NaN        NaN        NaN        NaN
# ...             ...         ...        ...        ...        ...        ...
# 421565        64.88       3.997    4556.61      20.64       1.50    1601.01
# 421566        64.89       3.985    5046.74        NaN      18.82    2253.43
# 421567        54.47       4.000    1956.28        NaN       7.89     599.32
# 421568        56.47       3.969    2004.02        NaN       3.18     437.73
# 421569        58.85       3.882    4018.91      58.08     100.00     211.94
#
#         MarkDown5         CPI  Unemployment
# 0             NaN  211.096358         8.106
# 1             NaN  211.242170         8.106
# 2             NaN  211.289143         8.106
# 3             NaN  211.319643         8.106
# 4             NaN  211.350143         8.106
# ...           ...         ...           ...
# 421565    3288.25  192.013558         8.684
# 421566    2340.01  192.170412         8.667
# 421567    3990.54  192.327265         8.667
# 421568    1537.49  192.330854         8.667
# 421569     858.33  192.308899         8.667
#
# [421570 rows x 16 columns]

# %%
df_merged.describe()
# Out:
#                Store           Dept   Weekly_Sales           Size  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123  136727.915739
# std        12.785297      30.492054   22711.183519   60980.583328
# min         1.000000       1.000000   -4988.940000   34875.000000
# 25%        11.000000      18.000000    2079.650000   93638.000000
# 50%        22.000000      37.000000    7612.030000  140167.000000
# 75%        33.000000      74.000000   20205.852500  202505.000000
# max        45.000000      99.000000  693099.360000  219622.000000
#
#          Temperature     Fuel_Price      MarkDown1      MarkDown2  \
# count  421570.000000  421570.000000  150681.000000  111248.000000
# mean       60.090059       3.361027    7246.420196    3334.628621
# std        18.447931       0.458515    8291.221345    9475.357325
# min        -2.060000       2.472000       0.270000    -265.760000
# 25%        46.680000       2.933000    2240.270000      41.600000
# 50%        62.090000       3.452000    5347.450000     192.000000
# 75%        74.280000       3.738000    9210.900000    1926.940000
# max       100.140000       4.468000   88646.760000  104519.540000
#
#            MarkDown3      MarkDown4      MarkDown5            CPI  \
# count  137091.000000  134967.000000  151432.000000  421570.000000
# mean     1439.421384    3383.168256    4628.975079     171.201947
# std      9623.078290    6292.384031    5962.887455      39.159276
# min       -29.100000       0.220000     135.160000     126.064000
# 25%         5.080000     504.220000    1878.440000     132.022667
# 50%        24.600000    1481.310000    3359.450000     182.318780
# 75%       103.990000    3595.040000    5563.800000     212.416993
# max    141630.610000   67474.850000  108519.280000     227.232807
#
#         Unemployment
# count  421570.000000
# mean        7.960289
# std         1.863296
# min         3.879000
# 25%         6.891000
# 50%         7.866000
# 75%         8.572000
# max        14.313000

# %% [markdown]
# Save merged Data Frame

# %%
df_merged.to_csv(data_preprocessed_dir+'/input_data_merged.csv', index=False)

# %% [markdown]
# # Data Visualization

# %%
def scatter(dataset, column):
    """
    Scater plots a columns of a dataset against the Weekly_sales
    
    :param dataset: Pandas.DataFrame to be visualized
    :param column: Name of column (str) to be plotted against Weekly_sales
    :return: None
    """
    plt.figure(figsize=(5, 2))
    plt.scatter(dataset[column], dataset['Weekly_Sales'])
    plt.ylabel('weeklySales')
    plt.xlabel(column)

# %%
scatter(df_merged, 'Fuel_Price')
scatter(df_merged, 'Size')
scatter(df_merged, 'CPI')
scatter(df_merged, 'Type')
scatter(df_merged, 'IsHoliday')
scatter(df_merged, 'Unemployment')
scatter(df_merged, 'Temperature')
scatter(df_merged, 'Store')
scatter(df_merged, 'Dept')

# %%
fig = plt.figure(figsize=(8, 4))
corr = df_merged.corr()
c = plt.pcolor(corr)
plt.yticks(np.arange(0.5, len(corr.index), 1), corr.index)
plt.xticks(np.arange(0.5, len(corr.columns), 1), corr.columns, rotation=45)
fig.colorbar(c)

# %%
#sns.pairplot(df_merged, vars=['Weekly_Sales', 'Fuel_Price',
#                              'Size', 'CPI', 'Dept', 'Temperature', 'Unemployment'])

# %%
# Replace the missing values (NA) with 0
sns.pairplot(df_merged.fillna(0), vars=[
             'Weekly_Sales', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5'])

# %% [markdown]
# # Plot Time Series on Department Level

# %% [markdown]
# Sample n random Store-Department combinations

# %%
store_i_dept_i = df_merged[['Store','Dept']].drop_duplicates().sample(n=3, random_state=1).values.tolist()

# %% [markdown]
# Plot time series

# %%
for si, di in store_i_dept_i:
    df_si_di = df_merged.loc[df_merged['Store'] == si].loc[df_merged['Dept'] == di][['Store','Dept','Date', 'Weekly_Sales']]
    df_si_di.plot(x='Date', y='Weekly_Sales', style='-', figsize=(12,2), title=f'Store {si}, Dept {di}')

# %% [markdown]
# Overlapping Time Series Plot

# %%
for si, di in store_i_dept_i:
    df_si_di = df_merged.loc[df_merged['Store'] == si].loc[df_merged['Dept'] == di][['Store','Dept','Date', 'Weekly_Sales']]
    df_si_di['year'] = pd.DatetimeIndex(df_si_di['Date']).year
    df_si_di['date_w/o_year'] = pd.DatetimeIndex(df_si_di['Date']).strftime('%m-%d')
    
    fig, ax = plt.subplots(figsize=(8,2))
    df_si_di.groupby('year').plot(x='date_w/o_year', y='Weekly_Sales', ax=ax, legend=False)
    ax.legend(df_si_di['year'].unique().tolist())
    ax.set_title(f'Store {si}, Dept {di}')

# %% [markdown]
# # Plot Time Series on Store Level

# %% [markdown]
# Sample n random Stores

# %%
store_i  = df_merged['Store'].drop_duplicates().sample(n=3, random_state=1).values.tolist()

# %% [markdown]
# Data Aggregation

# %%
df = df_merged[['Store','Dept','Date', 'Weekly_Sales']]
df = pd.pivot_table(df, values='Weekly_Sales', index=['Store', 'Date'], aggfunc=np.sum)
df.reset_index(level=df.index.names, inplace=True)

# %% [markdown]
# Plot time series

# %%
for s in store_i:
    df_s = df.loc[df['Store'] == s]
    df_s.plot(x='Date', y='Weekly_Sales', style='-', figsize=(12,2), title=f'Store {s}')

# %% [markdown]
# Overlapping Timeseries Plot

# %%
df['year'] = pd.DatetimeIndex(df['Date']).year
df['date_w/o_year'] = pd.DatetimeIndex(df['Date']).strftime('%m-%d')

for s in store_i:
    df_s = df.loc[df['Store'] == s]
    
    fig, ax = plt.subplots(figsize=(8,2))
    df_s.groupby('year').plot(x='date_w/o_year', y='Weekly_Sales', ax=ax, legend=False)
    ax.legend(df_s['year'].unique().tolist())
    ax.set_title(f'Store {s}')

# %% [markdown]
# # ACF & PACF

# %%
def plot_acf(pd_series, title=None):
    """
    Plot the auto-correlation function (ACF) of a time series 
    
    param pd_series: Pandas.Series of which the ACF should be visualized
    param title: Title of the plot (default: None)
    return: None
    """
    pd.DataFrame(acf(pd_series,nlags=52)).plot(kind="bar", figsize=(10,2), grid=True, legend=False)
    plt.xlabel("lag")
    plt.axhline(y=0.05, ls='--', color='red')
    plt.axhline(y=-0.05, ls='--', color='red')
    plt.title(title)

def plot_pacf(pd_series, title=None):
    """
    Plot the partial auto-correlation function (PACF) of a time series 
    
    param pd_series: Pandas.Series of which the PACF should be visualized
    param title: Title of the plot (default: None)
    return: None
    """
    pd.DataFrame(pacf(pd_series,nlags=52)).plot(kind="bar", figsize=(10,2), grid=True, legend=False)
                                       
    plt.xlabel("lag")
    plt.axhline(y=0.05, ls='--', color='red')
    plt.axhline(y=-0.05, ls='--', color='red')
    plt.title(title)

# %%
for s in store_i:
    plot_acf(df[df['Store'] == s]['Weekly_Sales'], f'ACF: Store {s}')
    plot_pacf(df[df['Store'] == s]['Weekly_Sales'], f'PACF: Store {s}')
# Out:
# c:\users\domin\anaconda3\envs\predicting-sales-data\lib\site-packages\statsmodels\tsa\stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning

# %% [markdown]
# # Periodogramm

# %%
def plot_spectrogram(pd_series, title=None):
    """
    Plot the spectrogram  of a time series 
    
    param pd_series: Pandas.Series of which the spectrogramm should be visualized
    param title: Title of the plot (default: None)
    return: None
    """
    freq, spectrum = periodogram(pd_series,scaling='spectrum')
    fig = plt.figure(figsize=(6, 3))
    plt.plot(freq, spectrum)
    plt.xlabel('Frequency [1/T]')
    plt.ylabel('Power Spectrum [V**2]')
    plt.title(title)
    plt.show()
    print('Most dominant cycles have length ',np.round(1/freq[spectrum.argsort()[-3:][::-1]],4).tolist())

# %%
for s in store_i:
    plot_spectrogram(df[df['Store'] == s]['Weekly_Sales'], title=f'Spectogram: Store {s}')
# Out:
# Most dominant cycles have length  [143.0, 47.6667, 71.5]
# Most dominant cycles have length  [47.6667, 143.0, 71.5]
# Most dominant cycles have length  [143.0, 13.0, 47.6667]
